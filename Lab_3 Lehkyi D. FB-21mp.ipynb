# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
# %matplotlib inline

# %% [markdown]
# # 1. Повнозв'язані нейронні мережі (Бінарна класифікація)

# %%
#https://www.kaggle.com/datasets/mssmartypants/water-quality
water = pd.read_csv('waterQuality.csv')

# %%
water = water.drop(labels=[7551,7568,7890],axis=0)
water['ammonia'] = water['ammonia'].astype(float)
water['is_safe'] = water['is_safe'].astype(int)

# %%
water_features = water.drop(['is_safe'],axis=1) #X
water_target = water['is_safe'] #y


X_train, X_test, y_train, y_test = train_test_split(water_features, water_target, test_size=0.20)

# %%
water_model_2_layers = keras.Sequential([
    layers.Dense(128, activation="relu"),
    layers.Dense(128, activation="relu"),
    layers.Dense(1, activation="sigmoid")
])

water_model_3_layers = keras.Sequential([
    layers.Dense(128, activation="relu"),
    layers.Dense(64, activation="relu"),
    layers.Dense(64, activation="relu"),
    layers.Dense(1, activation="sigmoid")
])

water_model_4_layers = keras.Sequential([
    layers.Dense(128, activation="relu"),
    layers.Dense(64, activation="relu"),
    layers.Dense(64, activation="relu"),
    layers.Dense(64, activation="relu"),
    layers.Dense(1, activation="sigmoid")
])

# %%
water_model_2_layers.compile(optimizer="rmsprop",
              loss="binary_crossentropy",
              metrics=["accuracy"])

water_model_3_layers.compile(optimizer="rmsprop",
              loss="binary_crossentropy",
              metrics=["accuracy"])

water_model_4_layers.compile(optimizer="rmsprop",
              loss="binary_crossentropy",
              metrics=["accuracy"])

# %%
history_2l = water_model_2_layers.fit(X_train,
                    y_train,
                    epochs=40,
                    validation_split=0.2)
# Out:
# Epoch 1/40
# C:\Users\GreenLHK\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\engine\data_adapter.py:1696: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   return t[start:end]
# 160/160 [==============================] - 1s 2ms/step - loss: 0.3453 - accuracy: 0.8741 - val_loss: 0.2918 - val_accuracy: 0.8914
# Epoch 2/40
# 160/160 [==============================] - 0s 1ms/step - loss: 0.2895 - accuracy: 0.8921 - val_loss: 0.2812 - val_accuracy: 0.8969
# Epoch 3/40
# 160/160 [==============================] - 0s 1ms/step - loss: 0.2769 - accuracy: 0.8921 - val_loss: 0.2757 - val_accuracy: 0.8898
# Epoch 4/40
# 160/160 [==============================] - 0s 1ms/step - loss: 0.2596 - accuracy: 0.8962 - val_loss: 0.2530 - val_accuracy: 0.9039
# Epoch 5/40
# 160/160 [==============================] - 0s 1ms/step - loss: 0.2498 - accuracy: 0.8995 - val_loss: 0.2867 - val_accuracy: 0.8922
# Epoch 6/40
# 160/160 [==============================] - 0s 1ms/step - loss: 0.2423 - accuracy: 0.9032 - val_loss: 0.2456 - val_accuracy: 0.9047
# Epoch 7/40
# 160/160 [==============================] - 0s 1ms/step - loss: 0.2301 - accuracy: 0.9095 - val_loss: 0.2590 - val_accuracy: 0.9000
# Epoch 8/40
# 160/160 [==============================] - 0s 1ms/step - loss: 0.2288 - accuracy: 0.9136 - val_loss: 0.2584 - val_accuracy: 0.8977
# Epoch 9/40
# 160/160 [==============================] - 0s 1ms/step - loss: 0.2226 - accuracy: 0.9105 - val_loss: 0.2347 - val_accuracy: 0.9141
# Epoch 10/40
# 160/160 [==============================] - 0s 1ms/step - loss: 0.2184 - accuracy: 0.9154 - val_loss: 0.2311 - val_accuracy: 0.9109
# Epoch 11/40
# 160/160 [==============================] - 0s 1ms/step - loss: 0.2143 - accuracy: 0.9187 - val_loss: 0.2285 - val_accuracy: 0.9172
# Epoch 12/40
# 160/160 [==============================] - 0s 1ms/step - loss: 0.2045 - accuracy: 0.9204 - val_loss: 0.2182 - val_accuracy: 0.9172
# Epoch 13/40
# 160/160 [==============================] - 0s 1ms/step - loss: 0.2029 - accuracy: 0.9247 - val_loss: 0.2359 - val_accuracy: 0.9156
# Epoch 14/40
# 160/160 [==============================] - 0s 1ms/step - loss: 0.1994 - accuracy: 0.9216 - val_loss: 0.2038 - val_accuracy: 0.9297
# Epoch 15/40
# 160/160 [==============================] - 0s 1ms/step - loss: 0.1939 - accuracy: 0.9275 - val_loss: 0.2103 - val_accuracy: 0.9273
# Epoch 16/40
# 160/160 [==============================] - 0s 1ms/step - loss: 0.1908 - accuracy: 0.9310 - val_loss: 0.2400 - val_accuracy: 0.9180
# Epoch 17/40
# 160/160 [==============================] - 0s 1ms/step - loss: 0.1883 - accuracy: 0.9287 - val_loss: 0.2221 - val_accuracy: 0.9203
# Epoch 18/40
# 160/160 [==============================] - 0s 1ms/step - loss: 0.1821 - accuracy: 0.9341 - val_loss: 0.1944 - val_accuracy: 0.9383
# Epoch 19/40
# 160/160 [==============================] - 0s 1ms/step - loss: 0.1798 - accuracy: 0.9330 - val_loss: 0.2153 - val_accuracy: 0.9273
# Epoch 20/40
# 160/160 [==============================] - 0s 1ms/step - loss: 0.1758 - accuracy: 0.9343 - val_loss: 0.2002 - val_accuracy: 0.9273
# Epoch 21/40
# 160/160 [==============================] - 0s 1ms/step - loss: 0.1721 - accuracy: 0.9359 - val_loss: 0.2155 - val_accuracy: 0.9297
# Epoch 22/40
# 160/160 [==============================] - 0s 1ms/step - loss: 0.1699 - accuracy: 0.9349 - val_loss: 0.1974 - val_accuracy: 0.9328
# Epoch 23/40
# 160/160 [==============================] - 0s 1ms/step - loss: 0.1703 - accuracy: 0.9367 - val_loss: 0.1885 - val_accuracy: 0.9289
# Epoch 24/40
# 160/160 [==============================] - 0s 1ms/step - loss: 0.1638 - accuracy: 0.9365 - val_loss: 0.2177 - val_accuracy: 0.9211
# Epoch 25/40
# 160/160 [==============================] - 0s 1ms/step - loss: 0.1642 - accuracy: 0.9380 - val_loss: 0.1893 - val_accuracy: 0.9312
# Epoch 26/40
# 160/160 [==============================] - 0s 1ms/step - loss: 0.1628 - accuracy: 0.9369 - val_loss: 0.1825 - val_accuracy: 0.9273
# Epoch 27/40
# 160/160 [==============================] - 0s 1ms/step - loss: 0.1602 - accuracy: 0.9390 - val_loss: 0.1821 - val_accuracy: 0.9375
# Epoch 28/40
# 160/160 [==============================] - 0s 1ms/step - loss: 0.1572 - accuracy: 0.9402 - val_loss: 0.2051 - val_accuracy: 0.9312
# Epoch 29/40
# 160/160 [==============================] - 0s 1ms/step - loss: 0.1542 - accuracy: 0.9425 - val_loss: 0.1843 - val_accuracy: 0.9375
# Epoch 30/40
# 160/160 [==============================] - 0s 1ms/step - loss: 0.1561 - accuracy: 0.9406 - val_loss: 0.2006 - val_accuracy: 0.9281
# Epoch 31/40
# 160/160 [==============================] - 0s 1ms/step - loss: 0.1488 - accuracy: 0.9406 - val_loss: 0.2334 - val_accuracy: 0.9375
# Epoch 32/40
# 160/160 [==============================] - 0s 1ms/step - loss: 0.1493 - accuracy: 0.9429 - val_loss: 0.1933 - val_accuracy: 0.9344
# Epoch 33/40
# 160/160 [==============================] - 0s 1ms/step - loss: 0.1492 - accuracy: 0.9431 - val_loss: 0.1847 - val_accuracy: 0.9328
# Epoch 34/40
# 160/160 [==============================] - 0s 1ms/step - loss: 0.1449 - accuracy: 0.9447 - val_loss: 0.2048 - val_accuracy: 0.9398
# Epoch 35/40
# 160/160 [==============================] - 0s 1ms/step - loss: 0.1427 - accuracy: 0.9476 - val_loss: 0.2057 - val_accuracy: 0.9289
# Epoch 36/40
# 160/160 [==============================] - 0s 1ms/step - loss: 0.1432 - accuracy: 0.9490 - val_loss: 0.1792 - val_accuracy: 0.9367
# Epoch 37/40
# 160/160 [==============================] - 0s 1ms/step - loss: 0.1373 - accuracy: 0.9455 - val_loss: 0.2329 - val_accuracy: 0.9414
# Epoch 38/40
# 160/160 [==============================] - 0s 1ms/step - loss: 0.1421 - accuracy: 0.9461 - val_loss: 0.1901 - val_accuracy: 0.9266
# Epoch 39/40
# 160/160 [==============================] - 0s 1ms/step - loss: 0.1365 - accuracy: 0.9480 - val_loss: 0.2003 - val_accuracy: 0.9367
# Epoch 40/40
# 160/160 [==============================] - 0s 1ms/step - loss: 0.1366 - accuracy: 0.9464 - val_loss: 0.2027 - val_accuracy: 0.9352

# %%
history_3l = water_model_3_layers.fit(X_train,
                    y_train,
                    epochs=35,
                    validation_split=0.2)
# Out:
# Epoch 1/35
# C:\Users\GreenLHK\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\engine\data_adapter.py:1696: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   return t[start:end]
# 160/160 [==============================] - 1s 2ms/step - loss: 0.3285 - accuracy: 0.8800 - val_loss: 0.3051 - val_accuracy: 0.8852
# Epoch 2/35
# 160/160 [==============================] - 0s 1ms/step - loss: 0.2782 - accuracy: 0.8905 - val_loss: 0.2744 - val_accuracy: 0.8961
# Epoch 3/35
# 160/160 [==============================] - 0s 1ms/step - loss: 0.2648 - accuracy: 0.8917 - val_loss: 0.2666 - val_accuracy: 0.8945
# Epoch 4/35
# 160/160 [==============================] - 0s 1ms/step - loss: 0.2546 - accuracy: 0.8976 - val_loss: 0.3239 - val_accuracy: 0.8680
# Epoch 5/35
# 160/160 [==============================] - 0s 1ms/step - loss: 0.2476 - accuracy: 0.9013 - val_loss: 0.2524 - val_accuracy: 0.9008
# Epoch 6/35
# 160/160 [==============================] - 0s 1ms/step - loss: 0.2419 - accuracy: 0.9038 - val_loss: 0.2511 - val_accuracy: 0.9062
# Epoch 7/35
# 160/160 [==============================] - 0s 1ms/step - loss: 0.2350 - accuracy: 0.9072 - val_loss: 0.3007 - val_accuracy: 0.8828
# Epoch 8/35
# 160/160 [==============================] - 0s 1ms/step - loss: 0.2291 - accuracy: 0.9109 - val_loss: 0.2393 - val_accuracy: 0.9039
# Epoch 9/35
# 160/160 [==============================] - 0s 1ms/step - loss: 0.2264 - accuracy: 0.9099 - val_loss: 0.2319 - val_accuracy: 0.9062
# Epoch 10/35
# 160/160 [==============================] - 0s 1ms/step - loss: 0.2243 - accuracy: 0.9124 - val_loss: 0.2646 - val_accuracy: 0.9086
# Epoch 11/35
# 160/160 [==============================] - 0s 1ms/step - loss: 0.2185 - accuracy: 0.9134 - val_loss: 0.2242 - val_accuracy: 0.9172
# Epoch 12/35
# 160/160 [==============================] - 0s 1ms/step - loss: 0.2132 - accuracy: 0.9165 - val_loss: 0.2211 - val_accuracy: 0.9125
# Epoch 13/35
# 160/160 [==============================] - 0s 1ms/step - loss: 0.2105 - accuracy: 0.9183 - val_loss: 0.2551 - val_accuracy: 0.9062
# Epoch 14/35
# 160/160 [==============================] - 0s 1ms/step - loss: 0.2062 - accuracy: 0.9210 - val_loss: 0.2585 - val_accuracy: 0.9109
# Epoch 15/35
# 160/160 [==============================] - 0s 1ms/step - loss: 0.2054 - accuracy: 0.9204 - val_loss: 0.2248 - val_accuracy: 0.9273
# Epoch 16/35
# 160/160 [==============================] - 0s 1ms/step - loss: 0.1985 - accuracy: 0.9238 - val_loss: 0.2200 - val_accuracy: 0.9250
# Epoch 17/35
# 160/160 [==============================] - 0s 1ms/step - loss: 0.1958 - accuracy: 0.9240 - val_loss: 0.2122 - val_accuracy: 0.9250
# Epoch 18/35
# 160/160 [==============================] - 0s 1ms/step - loss: 0.1925 - accuracy: 0.9255 - val_loss: 0.2260 - val_accuracy: 0.9250
# Epoch 19/35
# 160/160 [==============================] - 0s 1ms/step - loss: 0.1878 - accuracy: 0.9259 - val_loss: 0.2792 - val_accuracy: 0.8930
# Epoch 20/35
# 160/160 [==============================] - 0s 1ms/step - loss: 0.1853 - accuracy: 0.9304 - val_loss: 0.2043 - val_accuracy: 0.9281
# Epoch 21/35
# 160/160 [==============================] - 0s 1ms/step - loss: 0.1831 - accuracy: 0.9300 - val_loss: 0.2163 - val_accuracy: 0.9211
# Epoch 22/35
# 160/160 [==============================] - 0s 1ms/step - loss: 0.1792 - accuracy: 0.9304 - val_loss: 0.2019 - val_accuracy: 0.9266
# Epoch 23/35
# 160/160 [==============================] - 0s 1ms/step - loss: 0.1732 - accuracy: 0.9343 - val_loss: 0.2060 - val_accuracy: 0.9281
# Epoch 24/35
# 160/160 [==============================] - 0s 1ms/step - loss: 0.1755 - accuracy: 0.9335 - val_loss: 0.2142 - val_accuracy: 0.9328
# Epoch 25/35
# 160/160 [==============================] - 0s 1ms/step - loss: 0.1713 - accuracy: 0.9357 - val_loss: 0.2009 - val_accuracy: 0.9258
# Epoch 26/35
# 160/160 [==============================] - 0s 1ms/step - loss: 0.1715 - accuracy: 0.9382 - val_loss: 0.2464 - val_accuracy: 0.9336
# Epoch 27/35
# 160/160 [==============================] - 0s 1ms/step - loss: 0.1661 - accuracy: 0.9361 - val_loss: 0.2051 - val_accuracy: 0.9320
# Epoch 28/35
# 160/160 [==============================] - 0s 1ms/step - loss: 0.1671 - accuracy: 0.9347 - val_loss: 0.2044 - val_accuracy: 0.9242
# Epoch 29/35
# 160/160 [==============================] - 0s 1ms/step - loss: 0.1643 - accuracy: 0.9396 - val_loss: 0.2123 - val_accuracy: 0.9305
# Epoch 30/35
# 160/160 [==============================] - 0s 1ms/step - loss: 0.1618 - accuracy: 0.9390 - val_loss: 0.2263 - val_accuracy: 0.9320
# Epoch 31/35
# 160/160 [==============================] - 0s 1ms/step - loss: 0.1595 - accuracy: 0.9406 - val_loss: 0.2067 - val_accuracy: 0.9273
# Epoch 32/35
# 160/160 [==============================] - 0s 1ms/step - loss: 0.1579 - accuracy: 0.9419 - val_loss: 0.2248 - val_accuracy: 0.9164
# Epoch 33/35
# 160/160 [==============================] - 0s 1ms/step - loss: 0.1561 - accuracy: 0.9398 - val_loss: 0.2131 - val_accuracy: 0.9336
# Epoch 34/35
# 160/160 [==============================] - 0s 1ms/step - loss: 0.1590 - accuracy: 0.9421 - val_loss: 0.2264 - val_accuracy: 0.9305
# Epoch 35/35
# 160/160 [==============================] - 0s 1ms/step - loss: 0.1502 - accuracy: 0.9445 - val_loss: 0.2539 - val_accuracy: 0.9320

# %%
history_4l = water_model_4_layers.fit(X_train,
                    y_train,
                    epochs=30,
                    validation_split=0.2)
# Out:
# Epoch 1/30
# C:\Users\GreenLHK\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\engine\data_adapter.py:1696: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   return t[start:end]
# 160/160 [==============================] - 1s 2ms/step - loss: 0.3167 - accuracy: 0.8761 - val_loss: 0.2832 - val_accuracy: 0.8914
# Epoch 2/30
# 160/160 [==============================] - 0s 1ms/step - loss: 0.2765 - accuracy: 0.8919 - val_loss: 0.2699 - val_accuracy: 0.8922
# Epoch 3/30
# 160/160 [==============================] - 0s 1ms/step - loss: 0.2606 - accuracy: 0.8956 - val_loss: 0.2699 - val_accuracy: 0.9008
# Epoch 4/30
# 160/160 [==============================] - 0s 1ms/step - loss: 0.2507 - accuracy: 0.9019 - val_loss: 0.2584 - val_accuracy: 0.9039
# Epoch 5/30
# 160/160 [==============================] - 0s 1ms/step - loss: 0.2435 - accuracy: 0.9044 - val_loss: 0.2508 - val_accuracy: 0.9023
# Epoch 6/30
# 160/160 [==============================] - 0s 1ms/step - loss: 0.2371 - accuracy: 0.9044 - val_loss: 0.2577 - val_accuracy: 0.9086
# Epoch 7/30
# 160/160 [==============================] - 0s 1ms/step - loss: 0.2279 - accuracy: 0.9120 - val_loss: 0.2642 - val_accuracy: 0.9070
# Epoch 8/30
# 160/160 [==============================] - 0s 1ms/step - loss: 0.2254 - accuracy: 0.9124 - val_loss: 0.2334 - val_accuracy: 0.9094
# Epoch 9/30
# 160/160 [==============================] - 0s 1ms/step - loss: 0.2231 - accuracy: 0.9152 - val_loss: 0.2216 - val_accuracy: 0.9141
# Epoch 10/30
# 160/160 [==============================] - 0s 1ms/step - loss: 0.2184 - accuracy: 0.9132 - val_loss: 0.2363 - val_accuracy: 0.9102
# Epoch 11/30
# 160/160 [==============================] - 0s 1ms/step - loss: 0.2124 - accuracy: 0.9152 - val_loss: 0.2281 - val_accuracy: 0.9242
# Epoch 12/30
# 160/160 [==============================] - 0s 1ms/step - loss: 0.2080 - accuracy: 0.9224 - val_loss: 0.2302 - val_accuracy: 0.9156
# Epoch 13/30
# 160/160 [==============================] - 0s 1ms/step - loss: 0.2056 - accuracy: 0.9181 - val_loss: 0.2333 - val_accuracy: 0.9219
# Epoch 14/30
# 160/160 [==============================] - 0s 1ms/step - loss: 0.1972 - accuracy: 0.9249 - val_loss: 0.2475 - val_accuracy: 0.9148
# Epoch 15/30
# 160/160 [==============================] - 0s 1ms/step - loss: 0.1980 - accuracy: 0.9234 - val_loss: 0.2503 - val_accuracy: 0.9148
# Epoch 16/30
# 160/160 [==============================] - 0s 1ms/step - loss: 0.1937 - accuracy: 0.9275 - val_loss: 0.2228 - val_accuracy: 0.9219
# Epoch 17/30
# 160/160 [==============================] - 0s 1ms/step - loss: 0.1852 - accuracy: 0.9308 - val_loss: 0.2112 - val_accuracy: 0.9273
# Epoch 18/30
# 160/160 [==============================] - 0s 1ms/step - loss: 0.1872 - accuracy: 0.9292 - val_loss: 0.2129 - val_accuracy: 0.9250
# Epoch 19/30
# 160/160 [==============================] - 0s 1ms/step - loss: 0.1833 - accuracy: 0.9328 - val_loss: 0.2083 - val_accuracy: 0.9242
# Epoch 20/30
# 160/160 [==============================] - 0s 1ms/step - loss: 0.1803 - accuracy: 0.9332 - val_loss: 0.2049 - val_accuracy: 0.9281
# Epoch 21/30
# 160/160 [==============================] - 0s 1ms/step - loss: 0.1746 - accuracy: 0.9353 - val_loss: 0.2634 - val_accuracy: 0.9070
# Epoch 22/30
# 160/160 [==============================] - 0s 1ms/step - loss: 0.1751 - accuracy: 0.9367 - val_loss: 0.2056 - val_accuracy: 0.9297
# Epoch 23/30
# 160/160 [==============================] - 0s 1ms/step - loss: 0.1720 - accuracy: 0.9390 - val_loss: 0.2127 - val_accuracy: 0.9336
# Epoch 24/30
# 160/160 [==============================] - 0s 1ms/step - loss: 0.1662 - accuracy: 0.9388 - val_loss: 0.2210 - val_accuracy: 0.9234
# Epoch 25/30
# 160/160 [==============================] - 0s 1ms/step - loss: 0.1702 - accuracy: 0.9382 - val_loss: 0.2028 - val_accuracy: 0.9344
# Epoch 26/30
# 160/160 [==============================] - 0s 1ms/step - loss: 0.1654 - accuracy: 0.9384 - val_loss: 0.2469 - val_accuracy: 0.9273
# Epoch 27/30
# 160/160 [==============================] - 0s 1ms/step - loss: 0.1640 - accuracy: 0.9418 - val_loss: 0.2197 - val_accuracy: 0.9289
# Epoch 28/30
# 160/160 [==============================] - 0s 1ms/step - loss: 0.1645 - accuracy: 0.9394 - val_loss: 0.2098 - val_accuracy: 0.9344
# Epoch 29/30
# 160/160 [==============================] - 0s 1ms/step - loss: 0.1625 - accuracy: 0.9408 - val_loss: 0.2017 - val_accuracy: 0.9367
# Epoch 30/30
# 160/160 [==============================] - 0s 1ms/step - loss: 0.1612 - accuracy: 0.9419 - val_loss: 0.2107 - val_accuracy: 0.9375

# %%
water_model_2_layers.summary()
water_model_3_layers.summary()
water_model_4_layers.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 128)               2688
#
#  dense_1 (Dense)             (None, 128)               16512
#
#  dense_2 (Dense)             (None, 1)                 129
#
# =================================================================
# Total params: 19,329
# Trainable params: 19,329
# Non-trainable params: 0
# _________________________________________________________________
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_3 (Dense)             (None, 128)               2688
#
#  dense_4 (Dense)             (None, 64)                8256
#
#  dense_5 (Dense)             (None, 64)                4160
#
#  dense_6 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 15,169
# Trainable params: 15,169
# Non-trainable params: 0
# _________________________________________________________________
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_7 (Dense)             (None, 128)               2688
#
#  dense_8 (Dense)             (None, 64)                8256
#
#  dense_9 (Dense)             (None, 64)                4160
#
#  dense_10 (Dense)            (None, 64)                4160
#
#  dense_11 (Dense)            (None, 1)                 65
#
# =================================================================
# Total params: 19,329
# Trainable params: 19,329
# Non-trainable params: 0
# _________________________________________________________________

# %%
history_2l_dict = history_2l.history
history_2l_dict.keys()

history_3l_dict = history_3l.history

history_4l_dict = history_4l.history

# %%
def build_graphics(history_dict_data,model_name):
    fig = plt.figure(figsize=(12,6))
    fig.add_subplot(121)
    loss_values = history_dict_data["loss"]
    val_loss_values = history_dict_data["val_loss"]
    epochs = range(1, len(loss_values) + 1)
    plt.plot(epochs, loss_values, "r", label="Training loss")
    plt.plot(epochs, val_loss_values, "g", label="Validation loss")
    plt.title(model_name+" loss")
    plt.xlabel("Epochs num")
    plt.ylabel("Loss")
    plt.legend()
    
    fig.add_subplot(122)
    acc_values = history_dict_data["accuracy"]
    val_acc_values = history_dict_data["val_accuracy"]
    epochs = range(1, len(acc_values) + 1)
    plt.plot(epochs, acc_values, "r", label="Training accuracy")
    plt.plot(epochs, val_acc_values, "g", label="Validation accuracy")
    plt.title(model_name+" accuracy")
    plt.xlabel("Epochs num")
    plt.ylabel("Accuracy")
    plt.legend()
    
    plt.show()

# %%
build_graphics(history_2l_dict,"2 layers model")

build_graphics(history_3l_dict,"3 layers model")

build_graphics(history_4l_dict,"4 layers model")

# %%
result = water_model_2_layers.evaluate(X_test,y_test)
print('Test score:', result[0]) 
print('Test accuracy:', result[1])

result = water_model_3_layers.evaluate(X_test,y_test)
print('Test score:', result[0]) 
print('Test accuracy:', result[1])

result = water_model_4_layers.evaluate(X_test,y_test)
print('Test score:', result[0]) 
print('Test accuracy:', result[1])
# Out:
# 50/50 [==============================] - 0s 651us/step - loss: 0.1753 - accuracy: 0.9400
# Test score: 0.17531052231788635
# Test accuracy: 0.9399999976158142
# 50/50 [==============================] - 0s 692us/step - loss: 0.2253 - accuracy: 0.9356
# Test score: 0.2252577841281891
# Test accuracy: 0.9356250166893005
# 50/50 [==============================] - 0s 692us/step - loss: 0.1889 - accuracy: 0.9369
# Test score: 0.18885332345962524
# Test accuracy: 0.9368749856948853

# %% [markdown]
# # 2. Згорткові нейронні мережі (Класифікація зображень)

# %% [markdown]
# Посилання на датасет: https://www.kaggle.com/datasets/utkarshsaxenadn/animal-image-classification-dataset

# %%
import os
from PIL import Image
from sklearn.utils import shuffle
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

from tensorflow.keras.utils import load_img
from tensorflow.keras.utils import img_to_array
from tensorflow.keras.utils import array_to_img
from sklearn.model_selection import train_test_split

# %%
classes = ['Dog','Cat','Tiger','Zebra']

# %%
images_arr = []
images_names = []
classes_arr = []
folders = classes
class_id = 0

for folder in folders:
    for imgname in os.listdir(folder):
        image_sample = load_img(os.path.join(folder,imgname),target_size=(200,200))
        image_sample = img_to_array(image_sample)
        images_arr.append(image_sample)
        classes_arr.append(class_id)
        images_names.append(imgname)
    class_id+=1
            
images_arr = np.array(images_arr)
images_arr.shape
images_arr /= 255
images_arr[0]
# Out:
# array([[[0.5803922 , 0.654902  , 0.40392157],
#         [0.58431375, 0.65882355, 0.40784314],
#         [0.5882353 , 0.6627451 , 0.4117647 ],
#         ...,
#         [0.68235296, 0.6901961 , 0.44313726],
#         [0.68235296, 0.6901961 , 0.44313726],
#         [0.6784314 , 0.68235296, 0.44705883]],
#
#        [[0.5803922 , 0.654902  , 0.40392157],
#         [0.58431375, 0.65882355, 0.40784314],
#         [0.5882353 , 0.6627451 , 0.4117647 ],
#         ...,
#         [0.6745098 , 0.69411767, 0.44313726],
#         [0.68235296, 0.6901961 , 0.44313726],
#         [0.6784314 , 0.68235296, 0.44705883]],
#
#        [[0.5803922 , 0.654902  , 0.40392157],
#         [0.58431375, 0.65882355, 0.40784314],
#         [0.5882353 , 0.6627451 , 0.4117647 ],
#         ...,
#         [0.6745098 , 0.69411767, 0.44313726],
#         [0.68235296, 0.6901961 , 0.44313726],
#         [0.6784314 , 0.68235296, 0.44705883]],
#
#        ...,
#
#        [[0.41568628, 0.4862745 , 0.25882354],
#         [0.44705883, 0.5176471 , 0.2901961 ],
#         [0.41568628, 0.4862745 , 0.25882354],
#         ...,
#         [0.50980395, 0.5803922 , 0.34509805],
#         [0.54901963, 0.60784316, 0.3764706 ],
#         [0.4745098 , 0.5372549 , 0.29411766]],
#
#        [[0.41568628, 0.4862745 , 0.25882354],
#         [0.44705883, 0.5176471 , 0.2901961 ],
#         [0.41568628, 0.4862745 , 0.25882354],
#         ...,
#         [0.50980395, 0.5803922 , 0.34509805],
#         [0.54901963, 0.60784316, 0.3764706 ],
#         [0.4745098 , 0.5372549 , 0.29411766]],
#
#        [[0.39215687, 0.47058824, 0.23137255],
#         [0.42745098, 0.49803922, 0.2627451 ],
#         [0.40392157, 0.4745098 , 0.23921569],
#         ...,
#         [0.49803922, 0.5686275 , 0.33333334],
#         [0.5529412 , 0.62352943, 0.3882353 ],
#         [0.4627451 , 0.5254902 , 0.28235295]]], dtype=float32)

# %%
img_data = {
    "array": images_names,
    "class": classes_arr
}
img_data = pd.DataFrame(img_data)
img_data
# Out:
#                  array  class
# 0         Dog (1).jpeg      0
# 1          Dog (1).jpg      0
# 2        Dog (10).jpeg      0
# 3         Dog (10).jpg      0
# 4        Dog (100).jpg      0
# ...                ...    ...
# 7995  Zebra (995).jpeg      3
# 7996  Zebra (996).jpeg      3
# 7997  Zebra (997).jpeg      3
# 7998  Zebra (998).jpeg      3
# 7999  Zebra (999).jpeg      3
#
# [8000 rows x 2 columns]

# %%
sns.countplot(x='class', data = img_data)
# Out:
# <AxesSubplot: xlabel='class', ylabel='count'>

# %% [markdown]
# ### 0 - Dog
# ### 1 - Cat
# ### 2 - Tiger
# ### 3 - Zebra

# %%
image = array_to_img(images_arr[2000+2000])
plt.imshow(image)
print(classes_arr[2000+2000])
y = img_data['class']
y.shape
# Out:
# 2
# (8000,)

# %%
X_train, X_test, y_train, y_test = train_test_split(images_arr, img_data['class'], test_size=0.20)
y_train = np.asarray(y_train).astype(np.int32)
y_test = np.asarray(y_test).astype(np.int32)

y_train = tf.one_hot(y_train, 4)
y_test = tf.one_hot(y_test, 4)

# %%
#Creating model

alpha = 0.02

model = keras.Sequential()

model.add(layers.Conv2D(filters=16, kernel_size=(3, 3), padding="same", input_shape=(200,200,3)))
model.add(layers.LeakyReLU(alpha=alpha))
model.add(layers.MaxPooling2D(pool_size=(2, 2), padding='same'))

model.add(layers.Conv2D(filters=32, kernel_size=(3, 3), padding="same"))
model.add(layers.LeakyReLU(alpha=alpha))
model.add(layers.MaxPooling2D(pool_size=(2, 2), padding='same'))

model.add(layers.Conv2D(filters=64, kernel_size=(3, 3), padding="same"))
model.add(layers.MaxPooling2D(pool_size=(2, 2), padding='same'))


model.add(layers.Flatten())

model.add(layers.Dense(64))
model.add(layers.LeakyReLU(alpha=alpha))

model.add(layers.Dense(4, activation="softmax"))

model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 200, 200, 16)      448
#
#  leaky_re_lu (LeakyReLU)     (None, 200, 200, 16)      0
#
#  max_pooling2d (MaxPooling2D  (None, 100, 100, 16)     0
#  )
#
#  conv2d_1 (Conv2D)           (None, 100, 100, 32)      4640
#
#  leaky_re_lu_1 (LeakyReLU)   (None, 100, 100, 32)      0
#
#  max_pooling2d_1 (MaxPooling  (None, 50, 50, 32)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 50, 50, 64)        18496
#
#  max_pooling2d_2 (MaxPooling  (None, 25, 25, 64)       0
#  2D)
#
#  flatten (Flatten)           (None, 40000)             0
#
#  dense_12 (Dense)            (None, 64)                2560064
#
#  leaky_re_lu_2 (LeakyReLU)   (None, 64)                0
#
#  dense_13 (Dense)            (None, 4)                 260
#
# =================================================================
# Total params: 2,583,908
# Trainable params: 2,583,908
# Non-trainable params: 0
# _________________________________________________________________

# %%
history_img = model.fit(X_train,
                    y_train,
                    epochs=13,
                    validation_split=0.2,
                    verbose = 1)
# Out:
# Epoch 1/13
# 160/160 [==============================] - 50s 305ms/step - loss: 1.0091 - accuracy: 0.5695 - val_loss: 0.8500 - val_accuracy: 0.6484
# Epoch 2/13
# 160/160 [==============================] - 48s 302ms/step - loss: 0.6936 - accuracy: 0.7252 - val_loss: 0.7227 - val_accuracy: 0.7258
# Epoch 3/13
# 160/160 [==============================] - 48s 302ms/step - loss: 0.5759 - accuracy: 0.7816 - val_loss: 0.6298 - val_accuracy: 0.7539
# Epoch 4/13
# 160/160 [==============================] - 51s 317ms/step - loss: 0.4616 - accuracy: 0.8287 - val_loss: 0.5963 - val_accuracy: 0.7758
# Epoch 5/13
# 160/160 [==============================] - 49s 305ms/step - loss: 0.3865 - accuracy: 0.8582 - val_loss: 0.6143 - val_accuracy: 0.7797
# Epoch 6/13
# 160/160 [==============================] - 49s 304ms/step - loss: 0.2869 - accuracy: 0.8930 - val_loss: 0.6107 - val_accuracy: 0.7953
# Epoch 7/13
# 160/160 [==============================] - 49s 305ms/step - loss: 0.1768 - accuracy: 0.9371 - val_loss: 0.6567 - val_accuracy: 0.8117
# Epoch 8/13
# 160/160 [==============================] - 49s 309ms/step - loss: 0.1257 - accuracy: 0.9604 - val_loss: 1.0078 - val_accuracy: 0.7437
# Epoch 9/13
# 160/160 [==============================] - 50s 312ms/step - loss: 0.0874 - accuracy: 0.9725 - val_loss: 0.8550 - val_accuracy: 0.7867
# Epoch 10/13
# 160/160 [==============================] - 50s 313ms/step - loss: 0.0575 - accuracy: 0.9824 - val_loss: 0.9355 - val_accuracy: 0.8016
# Epoch 11/13
# 160/160 [==============================] - 50s 312ms/step - loss: 0.0300 - accuracy: 0.9934 - val_loss: 1.0052 - val_accuracy: 0.8102
# Epoch 12/13
# 160/160 [==============================] - 50s 314ms/step - loss: 0.0259 - accuracy: 0.9932 - val_loss: 1.1168 - val_accuracy: 0.8102
# Epoch 13/13
# 160/160 [==============================] - 51s 316ms/step - loss: 0.0302 - accuracy: 0.9914 - val_loss: 1.3178 - val_accuracy: 0.7695

# %%
history_img_dict = history_img.history

build_graphics(history_img_dict,"image classification model")

# %%
model.evaluate(X_test,y_test)
# Out:
# 50/50 [==============================] - 4s 78ms/step - loss: 1.3002 - accuracy: 0.7781
# [1.3001890182495117, 0.778124988079071]

# %% [markdown]
# # 3. Рекурентні нейронні мережі (Класифікація текстів)

# %% [markdown]
# Посилання на датасет:
# https://www.kaggle.com/datasets/chandramoulinaidu/spam-classification-for-basic-nlp

# %%
import re
import string
import nltk

from nltk.corpus import stopwords
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.model_selection import train_test_split
from bs4 import BeautifulSoup

# %%
spam_dataset = pd.read_csv('text_spam.csv')
spam_dataset = spam_dataset.drop(['FILE_NAME'], axis = 1)
spam_dataset.shape
# Out:
# (5796, 2)

# %%
spam_dataset.head(10)
# Out:
#    CATEGORY                                            MESSAGE
# 0         1  Dear Homeowner,\n\n \n\nInterest Rates are at ...
# 1         1  ATTENTION: This is a MUST for ALL Computer Use...
# 2         1  This is a multi-part message in MIME format.\n...
# 3         1  IMPORTANT INFORMATION:\n\n\n\nThe new domain n...
# 4         1  This is the bottom line.  If you can GIVE AWAY...
# 5         1  ------=_NextPart_000_00B8_51E06B6A.C8586B31\n\...
# 6         1  <STYLE type="text/css">\n\n<!--\n\nP{\n\n  fon...
# 7         1  <HR>\n\n<html>\n\n<head>\n\n  <title>Secured I...
# 8         1  <table width="600" border="20" align="center" ...
# 9         1  <html>\n\n\n\n<head>\n\n<meta http-equiv="Cont...

# %%
spam_dataset['CATEGORY'].value_counts()
# Out:
# 0    3900
# 1    1896
# Name: CATEGORY, dtype: int64

# %% [markdown]
# 1 - Spam, 0 - Not spam

# %%
stop_words = stopwords.words("english")
def clean_text(text):
    #видалення html тегів з тексту
    soup = BeautifulSoup(text)
    text = soup.get_text()
    text = text.lower()
    text = re.sub("@\S+", " ", text)
    text = re.sub("http*\S+", " ", text)
    text = re.sub("#\S+", " ", text)
    text = re.sub("\d", " ", text)
    text = re.sub('[%s]' % re.escape(string.punctuation), ' ', text)
    text = re.sub('\-\s\r\n\s{1,}|\-\s\r\n|\r\n', '', text)
    text = re.sub('\n', ' ', text)
    text = re.sub('\s',' ', text)
    text = ' '.join([word for word in text.split(' ') if word not in stop_words])
    #text = re.sub('\s[a-z]\s', " ", text)
    text = re.sub('\\b\\w{1,2}\\b', " ", text)
    odd_words = ['text','cdc','color','encoding','ffont','content','nbsp','2ffont','3darial','type','cfont','font','size','darial','list','charset','quoted','iso']
    for word in odd_words:
        text = re.sub('\s'+word+'\s', " ", text)
    text = re.sub('\s{2,}',' ', text)    
    return text

# %%
spam_dataset['MESSAGE'] = spam_dataset['MESSAGE'].apply(clean_text)
spam_dataset.head(10)
# Out:
# C:\Users\GreenLHK\AppData\Local\Programs\Python\Python310\lib\site-packages\bs4\__init__.py:435: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   warnings.warn(
# C:\Users\GreenLHK\AppData\Local\Programs\Python\Python310\lib\site-packages\bs4\__init__.py:404: MarkupResemblesLocatorWarning: The input looks more like a URL than markup. You may want to use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   warnings.warn(
#    CATEGORY                                            MESSAGE
# 0         1  dear homeowner interest rates lowest point yea...
# 1         1  attention must computer users new special pack...
# 2         1  multi part message mime format nextpart plain ...
# 3         1  important information new domain names finally...
# 4         1  bottom line give away free people like one mon...
# 5         1   nextpart plain transfer base sgvyzsdzihrozsbo...
# 6         1   hello chinese traditional × ¡ ¡ êà¼o×îóðð§µä...
# 7         1   secured investements wealth without risk disc...
# 8         1   click simply amateur like girl next door xxx ...
# 9         1   answer unlist information message brought ans...

# %%
from keras.preprocessing.text import Tokenizer

# %%
num_of_words = 5000
tokenizer = Tokenizer(num_of_words)
tokenizer.fit_on_texts(spam_dataset['MESSAGE'])

# %%
textSequences = tokenizer.texts_to_sequences(spam_dataset['MESSAGE'])
text_data = tf.keras.preprocessing.sequence.pad_sequences(textSequences, maxlen=500)
text_target = spam_dataset['CATEGORY']

# %%
model = keras.Sequential()
model.add(layers.Embedding(input_dim=num_of_words, output_dim=64,input_length=500))
model.add(layers.LSTM(units=128,return_sequences=True))
model.add(layers.LSTM(units=64))
model.add(layers.Dense(1, activation='sigmoid'))

# %%
model.compile(optimizer="adam",
              loss="binary_crossentropy",
              metrics=["accuracy"])

# %%
model.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 500, 64)           320000
#
#  lstm (LSTM)                 (None, 500, 128)          98816
#
#  lstm_1 (LSTM)               (None, 64)                49408
#
#  dense_14 (Dense)            (None, 1)                 65
#
# =================================================================
# Total params: 468,289
# Trainable params: 468,289
# Non-trainable params: 0
# _________________________________________________________________

# %%
X_train, X_test, y_train, y_test = train_test_split(text_data, text_target, test_size=0.20)

# %%
history = model.fit(X_train,
                    y_train,
                    epochs=5,
                    batch_size=128,
                    validation_split=0.2,
                    shuffle = True,
                    verbose = 1)
# Out:
# Epoch 1/5
# C:\Users\GreenLHK\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\engine\data_adapter.py:1696: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   return t[start:end]
# 29/29 [==============================] - 66s 2s/step - loss: 0.4138 - accuracy: 0.7907 - val_loss: 0.1288 - val_accuracy: 0.9526
# Epoch 2/5
# 29/29 [==============================] - 61s 2s/step - loss: 0.0501 - accuracy: 0.9857 - val_loss: 0.0540 - val_accuracy: 0.9806
# Epoch 3/5
# 29/29 [==============================] - 63s 2s/step - loss: 0.0205 - accuracy: 0.9949 - val_loss: 0.0437 - val_accuracy: 0.9806
# Epoch 4/5
# 29/29 [==============================] - 63s 2s/step - loss: 0.0116 - accuracy: 0.9976 - val_loss: 0.0454 - val_accuracy: 0.9849
# Epoch 5/5
# 29/29 [==============================] - 66s 2s/step - loss: 0.0083 - accuracy: 0.9973 - val_loss: 0.0614 - val_accuracy: 0.9881

# %%
history_dict_t = history.history
build_graphics(history_dict_t,"text model")

# %%
model.evaluate(X_test,y_test)
# Out:
# 37/37 [==============================] - 4s 100ms/step - loss: 0.0670 - accuracy: 0.9819
# [0.06700889766216278, 0.9818965792655945]
